# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE
import warnings
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
warnings.filterwarnings("ignore")

# %%
def execute_eval_HT(path_fake, path_real, list_features, seed):
    df_real = pd.read_csv(path_real)
    df_real['label'] = 0
    df_fake = pd.read_csv(path_fake)
    df_fake['label'] = 1
    df_fake_real = pd.concat([df_fake, df_real])
    train_X = df_fake_real[list_features]
    train_y = df_fake_real['label']
    sm = SMOTE(random_state=42)
    train_X, train_y = sm.fit_resample(train_X, train_y)
    strat_k_fold = KFold(n_splits=5, shuffle=True, random_state=seed)
    model = XGBClassifier(verbosity = 0)
    results_roc = cross_val_score(model, train_X, train_y, cv=strat_k_fold, scoring='roc_auc')
    results_precision = cross_val_score(model, train_X, train_y, cv=strat_k_fold, scoring='precision')
    results_recall = cross_val_score(model, train_X, train_y, cv=strat_k_fold, scoring='recall')
    results_f1 = cross_val_score(model, train_X, train_y, cv=strat_k_fold, scoring='f1')
    return results_roc, results_precision, results_recall, results_f1

# %%
def random_sampling_eval(path_fake, path_real, list_features, seed):
    df_real = pd.read_csv(path_real)
    df_real['label'] = 0
    df_fake = pd.read_csv(path_fake)
    df_fake['label'] = 1
    df_fake_real = pd.concat([df_fake, df_real])
    X = df_fake_real[list_features]
    y = df_fake_real['label']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=seed)
    sm = SMOTE(random_state=42)
    train_X, train_y = sm.fit_resample(X_train, y_train)
    
    model = XGBClassifier(verbosity = 0)
    model.fit(X_train, y_train)
    pred_results = model.predict(X_test)
    
    f1_val = f1_score(y_test, pred_results, average='binary')
    precision = precision_score(y_test, pred_results, average='binary')
    recall = recall_score(y_test, pred_results, average='binary')
    roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    return roc_auc, f1_val, precision, recall

# %%
df_all_results = pd.DataFrame()
df_all_results_f1 = pd.DataFrame()

# %% [markdown]
# ## Results BEFORE the mimicProp corrections

# %% [markdown]
# ## Top sentences BS

# %% [markdown]
# ### Bias-inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_top_fake.csv', 'BS_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_bs_bias'] = roc
df_all_results_f1['roc_top_bs_bias'] = f1
# Out:
# ROC auc: 0.5653113717128968 | STD: 0.057782686736499944
# Precision: 0.2633787425594701 | STD: 0.1313690208673362
# Recall: 0.10786369854047986 | STD: 0.05496915621514222
# F1 Score: 0.1482311475483934 | STD: 0.07131820280019903

# %% [markdown]
# ### MPQA Lexicons

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_top_fake.csv', 'BS_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_bs_mpqa'] = roc
df_all_results_f1['roc_top_bs_mpqa'] = f1
# Out:
# ROC auc: 0.559169922089457 | STD: 0.05260955144585457
# Precision: 0.2450369655695406 | STD: 0.09061692299378364
# Recall: 0.13926698309881425 | STD: 0.06485906806515078
# F1 Score: 0.17189567953965998 | STD: 0.06839582471970572

# %% [markdown]
# ### Deng et al., 2013

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_top_fake.csv', 'BS_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_bs_weibe'] = roc
df_all_results_f1['roc_top_bs_weibe'] = f1
# Out:
# ROC auc: 0.5696513155285335 | STD: 0.047730201489653325
# Precision: 0.25141421490745086 | STD: 0.11769517725932976
# Recall: 0.14334970567345456 | STD: 0.06897518834249258
# F1 Score: 0.17613655415191268 | STD: 0.07538231397320111

# %% [markdown]
# ### Todos os léxicos juntos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_top_fake.csv', 'BS_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_bs_all'] = roc
df_all_results_f1['roc_top_bs_all'] = f1
# Out:
# ROC auc: 0.6024942878966452 | STD: 0.05841486801003131
# Precision: 0.289278527028527 | STD: 0.17304612876162406
# Recall: 0.09842491728460119 | STD: 0.05624682724249953
# F1 Score: 0.14090668559602557 | STD: 0.07441278484988995

# %% [markdown]
# ## Entire BS

# %% [markdown]
# ### Bias inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_entire_fake.csv', 'BS_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_bs_bias'] = roc
df_all_results_f1['roc_entire_bs_bias'] = f1
# Out:
# ROC auc: 0.6875266666959012 | STD: 0.04881810350941775
# Precision: 0.5292351265499132 | STD: 0.10128633754787342
# Recall: 0.3042109270992692 | STD: 0.08317297270789431
# F1 Score: 0.37925258194312744 | STD: 0.0796918469368734

# %% [markdown]
# ### MPQA Lexicons

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_entire_fake.csv', 'BS_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_bs_mpqa'] = roc
df_all_results_f1['roc_entire_bs_mpqa'] = f1
# Out:
# ROC auc: 0.6143884320915629 | STD: 0.045995263860729246
# Precision: 0.35898401607878583 | STD: 0.09668206478089136
# Recall: 0.22645977378185198 | STD: 0.07943027150738549
# F1 Score: 0.2703166487756531 | STD: 0.07406937842748995

# %% [markdown]
# ### Deng at al. 2013

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_entire_fake.csv', 'BS_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_bs_weibe'] = roc
df_all_results_f1['roc_entire_bs_weibe'] = f1
# Out:
# ROC auc: 0.6701205278264688 | STD: 0.05184759532958968
# Precision: 0.4040058701965688 | STD: 0.0983405760620519
# Recall: 0.2723588943659395 | STD: 0.08018509319287052
# F1 Score: 0.320740435857075 | STD: 0.08006969579624393

# %% [markdown]
# ### Todos os léxicos juntos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('BS_entire_fake.csv', 'BS_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_bs_all'] = roc
df_all_results_f1['roc_entire_bs_all'] = f1
# Out:
# ROC auc: 0.7402279109115918 | STD: 0.043634672182003766
# Precision: 0.5821512289833228 | STD: 0.10673268370561476
# Recall: 0.33550590706576117 | STD: 0.07140338192185303
# F1 Score: 0.4187618232087476 | STD: 0.06929208699390073

# %% [markdown]
# ## Top COVID

# %% [markdown]
# ### Bias-inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_top_fake.csv', 'COVID_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_covid_bias'] = roc
df_all_results_f1['roc_top_covid_bias'] = f1
# Out:
# ROC auc: 0.6657148202467748 | STD: 0.018416632218374356
# Precision: 0.5335707102867758 | STD: 0.04066131050232191
# Recall: 0.37838223433531487 | STD: 0.03371042865005419
# F1 Score: 0.44199777436544657 | STD: 0.03246451486480071

# %% [markdown]
# ### MPQA

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_top_fake.csv', 'COVID_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_covid_mpqa'] = roc
df_all_results_f1['roc_top_covid_mpqa'] = f1
# Out:
# ROC auc: 0.6554136723452895 | STD: 0.019121530622404816
# Precision: 0.5265398924452458 | STD: 0.03708039745989454
# Recall: 0.3662617000581634 | STD: 0.0308196443913302
# F1 Score: 0.4311101433573014 | STD: 0.027789130560637292

# %% [markdown]
# ### Deng

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_top_fake.csv', 'COVID_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_covid_weibe'] = roc
df_all_results_f1['roc_top_covid_weibe'] = f1
# Out:
# ROC auc: 0.6399617603010609 | STD: 0.02111272813831187
# Precision: 0.5139422281160333 | STD: 0.0431753395443393
# Recall: 0.34372782843119476 | STD: 0.030716049202631705
# F1 Score: 0.41098756468394165 | STD: 0.029903329380561245

# %% [markdown]
# ### Todos os léxicos juntos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_top_fake.csv', 'COVID_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_covid_all'] = roc
df_all_results_f1['roc_top_covid_all'] = f1
# Out:
# ROC auc: 0.7152978489549712 | STD: 0.019352094116906235
# Precision: 0.5924574687947766 | STD: 0.035026261348517065
# Recall: 0.4476252825540961 | STD: 0.03074111445523648
# F1 Score: 0.5092230273646638 | STD: 0.02686869699217859

# %% [markdown]
# ## Entire COVID

# %% [markdown]
# ### Bias-inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_entire_fake.csv', 'COVID_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_covid_bias'] = roc
df_all_results_f1['roc_entire_covid_bias'] = f1
# Out:
# ROC auc: 0.6796824153626043 | STD: 0.02008549333980464
# Precision: 0.5388354164619392 | STD: 0.036921597608268054
# Recall: 0.408222432485814 | STD: 0.03069950692771911
# F1 Score: 0.4639229749377225 | STD: 0.029363631419145175

# %% [markdown]
# ### MPQA

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_entire_fake.csv', 'COVID_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_covid_mpqa'] = roc
df_all_results_f1['roc_entire_covid_mpqa'] = f1
# Out:
# ROC auc: 0.6751926184739623 | STD: 0.019181571051434837
# Precision: 0.5389124747887105 | STD: 0.03605573835242531
# Recall: 0.3970563353740002 | STD: 0.031335813617312594
# F1 Score: 0.45637766672961017 | STD: 0.0272586452356912

# %% [markdown]
# ### Deng

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_entire_fake.csv', 'COVID_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_covid_weibe'] = roc
df_all_results_f1['roc_entire_covid_weibe'] = f1
# Out:
# ROC auc: 0.635144365681658 | STD: 0.020546178503023853
# Precision: 0.5026781281624622 | STD: 0.03501636653321152
# Recall: 0.3502401544085535 | STD: 0.029595360671531224
# F1 Score: 0.4118862024802202 | STD: 0.026025605922744745

# %% [markdown]
# ### Todos os léxicos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('COVID_entire_fake.csv', 'COVID_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_covid_all'] = roc
df_all_results_f1['roc_entire_covid_all'] = f1
# Out:
# ROC auc: 0.7259202180121476 | STD: 0.019217642506165648
# Precision: 0.5777950334892533 | STD: 0.03278335307858647
# Recall: 0.4543010448751195 | STD: 0.03199173228617749
# F1 Score: 0.5079298230501068 | STD: 0.026727946646917952

# %% [markdown]
# ## Top CELEBRITY

# %% [markdown]
# ### bias-inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_top_fake.csv', 'CELEBRITY_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_celeb_bias'] = roc
df_all_results_f1['roc_top_celeb_bias'] = f1
# Out:
# ROC auc: 0.5307457188906455 | STD: 0.057431528907943646
# Precision: 0.5165964035750584 | STD: 0.0651139767677615
# Recall: 0.5342402506857415 | STD: 0.07478252128848482
# F1 Score: 0.5220472027453674 | STD: 0.05686368477003963

# %% [markdown]
# ### MPQA

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_top_fake.csv', 'CELEBRITY_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_celeb_mpqa'] = roc
df_all_results_f1['roc_top_celeb_mpqa'] = f1
# Out:
# ROC auc: 0.5814834491042179 | STD: 0.049004425690781235
# Precision: 0.5409963786354264 | STD: 0.06819627699673024
# Recall: 0.5458471146674421 | STD: 0.0759247382386899
# F1 Score: 0.5396945527526622 | STD: 0.05663543482467296

# %% [markdown]
# ### Deng

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_top_fake.csv', 'CELEBRITY_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_celeb_weibe'] = roc
df_all_results_f1['roc_top_celeb_weibe'] = f1
# Out:
# ROC auc: 0.528979584693314 | STD: 0.05756386765716666
# Precision: 0.5174545120254446 | STD: 0.0649708445244314
# Recall: 0.5197467946255339 | STD: 0.06411021660089708
# F1 Score: 0.5158733872489889 | STD: 0.05322781593846488

# %% [markdown]
# ### Todos os léxicos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_top_fake.csv', 'CELEBRITY_top_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_top_celeb_all'] = roc
df_all_results_f1['roc_top_celeb_all'] = f1
# Out:
# ROC auc: 0.5716981594489552 | STD: 0.05476219208111719
# Precision: 0.5436242339304497 | STD: 0.06891901044185375
# Recall: 0.5464543925365664 | STD: 0.07774894022950296
# F1 Score: 0.5411885343912618 | STD: 0.05831018393690405

# %% [markdown]
# ## Entire CELEBRITY

# %% [markdown]
# ### Bias-inducing terms

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_entire_fake.csv', 'CELEBRITY_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_celeb_bias'] = roc
df_all_results_f1['roc_entire_celeb_bias'] = f1
# Out:
# ROC auc: 0.5750717222309656 | STD: 0.04905125322352203
# Precision: 0.5470892679206912 | STD: 0.0671553359977046
# Recall: 0.5563901765875607 | STD: 0.06844075821964417
# F1 Score: 0.5483695088324457 | STD: 0.052220523240501054

# %% [markdown]
# ### MPQA

# %%
features = ['positive','negative']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_entire_fake.csv', 'CELEBRITY_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_celeb_mpqa'] = roc
df_all_results_f1['roc_entire_celeb_mpqa'] = f1
# Out:
# ROC auc: 0.6539400028621274 | STD: 0.049791529987449054
# Precision: 0.6166952881370942 | STD: 0.06713185101742611
# Recall: 0.6204439740291647 | STD: 0.07950329493378344
# F1 Score: 0.6147829664212692 | STD: 0.05543846449019883

# %% [markdown]
# ### Deng

# %%
features = ['pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_entire_fake.csv', 'CELEBRITY_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_celeb_weibe'] = roc
df_all_results_f1['roc_entire_celeb_weibe'] = f1
# Out:
# ROC auc: 0.5763267948856344 | STD: 0.04094536067337129
# Precision: 0.5546078644506991 | STD: 0.05905126972043441
# Recall: 0.55023614004705 | STD: 0.06330066857133065
# F1 Score: 0.5491490637309545 | STD: 0.04574826125064014

# %% [markdown]
# ### Todos os léxicos

# %%
features = ['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs', 'positive','negative', 'pos_effect','neg_effect']
roc = []
precision = []
recall = []
f1 = []
for i in range(100):
    roc_val, f1_val, precision_val, recall_val = random_sampling_eval('CELEBRITY_entire_fake.csv', 'CELEBRITY_entire_real.csv', features, i)
    roc.append(roc_val)
    f1.append(f1_val)
    precision.append(precision_val)
    recall.append(recall_val)
print('ROC auc: ' + str(np.mean(roc)) + " | STD: " + str(np.std(roc)))
print('Precision: ' + str(np.mean(precision)) + " | STD: " + str(np.std(precision)))
print('Recall: ' + str(np.mean(recall)) + " | STD: " + str(np.std(recall)))
print('F1 Score: ' + str(np.mean(f1)) + " | STD: " + str(np.std(f1)))
df_all_results['roc_entire_celeb_all'] = roc
df_all_results_f1['roc_entire_celeb_all'] = f1
# Out:
# ROC auc: 0.667555590928199 | STD: 0.04707548362209388
# Precision: 0.6197821275559856 | STD: 0.06847770322654385
# Recall: 0.635290362597758 | STD: 0.07614165376542313
# F1 Score: 0.6235930941781632 | STD: 0.05472913622440697

# %%
df_all_results.to_csv('df_results_baselines.csv', index=False)
df_all_results_f1.to_csv('df_results_baselines_f1.csv', index=False)

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
def SHAP_analysis(path_real, path_fake):
    df_real = pd.read_csv(path_real)
    df_real['label'] = 0
    df_fake = pd.read_csv(path_fake)
    df_fake['label'] = 1
    df_fake_real = pd.concat([df_fake, df_real])
    df_fake_real = df_fake_real[['label','assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs']]
    train_X = df_fake_real.loc[:, 'assertives':'report_verbs']
    train_y = df_fake_real['label']
    model = XGBClassifier(n_jobs=4)
    model.fit(train_X, train_y)
    X_train_arr = train_X
    shap_values = shap.TreeExplainer(model).shap_values(X_train_arr)
    shap.summary_plot(shap_values, X_train_arr, feature_names=['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs'], plot_type='bar')
    shap.summary_plot(shap_values, X_train_arr, feature_names=['assertives','bias', 'factive_verbs','hedges','implicative_verbs','report_verbs'], plot_type='dot')

# %% [markdown]
# ## SHAP analysis of model trained with BS dataset

# %%
SHAP_analysis('BS_top_real.csv', 'BS_top_fake.csv')
# Out:
# [01:17:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## SHAP analysis of model trained with COVID data

# %%
SHAP_analysis('COVID_top_real.csv', 'COVID_top_fake.csv')
# Out:
# [01:17:59] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## SHAP analysis of model trained with CELEBRITY data

# %%
SHAP_analysis('CELEBRITY_top_real.csv', 'CELEBRITY_top_fake.csv')
# Out:
# [01:18:10] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
df_real = pd.read_csv('CELEBRITY_top_real_HT.csv')
df_fake = pd.read_csv('CELEBRITY_top_fake_HT.csv')
print("real: ", len(df_real))
print("fake: ", len(df_fake))
# Out:
# real:  249
# fake:  249
